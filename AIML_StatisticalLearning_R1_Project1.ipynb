# %%
import pandas as pd

# %%
df1 = pd.read_csv("Laliga.csv", header=1)
df1
# Out:
#     Pos                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1          Real Madrid       86   4385        2762     1647        552
# 1     2            Barcelona       86   4262        2762     1581        573
# 2     3      Atletico Madrid       80   3442        2614     1241        598
# 3     4             Valencia       82   3386        2664     1187        616
# 4     5      Athletic Bilbao       86   3368        2762     1209        633
# 5     6              Sevilla       73   2819        2408      990        531
# 6     7             Espanyol       82   2792        2626      948        608
# 7     8        Real Sociedad       70   2573        2302      864        577
# 8     9             Zaragoza       58   2109        1986      698        522
# 9    10           Real Betis       51   1884        1728      606        440
# 10   11  Deportivo La Coruna       45   1814        1530      563        392
# ...

# %% [markdown]
# Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data.

# %%
df2 = pd.read_csv("Laliga.csv", header=1, na_values = ["-"])
df2.head(10)
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 0    1      Real Madrid       86  4385.0       2762.0    1647.0       552.0
# 1    2        Barcelona       86  4262.0       2762.0    1581.0       573.0
# 2    3  Atletico Madrid       80  3442.0       2614.0    1241.0       598.0
# 3    4         Valencia       82  3386.0       2664.0    1187.0       616.0
# 4    5  Athletic Bilbao       86  3368.0       2762.0    1209.0       633.0
# 5    6          Sevilla       73  2819.0       2408.0     990.0       531.0
# 6    7         Espanyol       82  2792.0       2626.0     948.0       608.0
# 7    8    Real Sociedad       70  2573.0       2302.0     864.0       577.0
# 8    9         Zaragoza       58  2109.0       1986.0     698.0       522.0
# 9   10       Real Betis       51  1884.0       1728.0     606.0       440.0
#
#    GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth  \
# ...

# %%
df3 = df2.fillna(0)
df3
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0     1          Real Madrid       86  4385.0       2762.0    1647.0
# 1     2            Barcelona       86  4262.0       2762.0    1581.0
# 2     3      Atletico Madrid       80  3442.0       2614.0    1241.0
# 3     4             Valencia       82  3386.0       2664.0    1187.0
# 4     5      Athletic Bilbao       86  3368.0       2762.0    1209.0
# 5     6              Sevilla       73  2819.0       2408.0     990.0
# 6     7             Espanyol       82  2792.0       2626.0     948.0
# 7     8        Real Sociedad       70  2573.0       2302.0     864.0
# 8     9             Zaragoza       58  2109.0       1986.0     698.0
# 9    10           Real Betis       51  1884.0       1728.0     606.0
# 10   11  Deportivo La Coruna       45  1814.0       1530.0     563.0
# 11   12           Celta Vigo       51  1789.0       1698.0     586.0
# 12   13           Valladolid       42  1471.0       1466.0     463.0
# ...

# %% [markdown]
# Print all the teams which have started playing between 1930-1980.

# %%
pd.to_datetime(df3.Debut, errors='ignore')
df3.head()
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 0    1      Real Madrid       86  4385.0       2762.0    1647.0       552.0
# 1    2        Barcelona       86  4262.0       2762.0    1581.0       573.0
# 2    3  Atletico Madrid       80  3442.0       2614.0    1241.0       598.0
# 3    4         Valencia       82  3386.0       2664.0    1187.0       616.0
# 4    5  Athletic Bilbao       86  3368.0       2762.0    1209.0       633.0
#
#    GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth  \
# 0      563.0    5947.0        3140.0      33.0       23.0    8.0     8.0
# 1      608.0    5900.0        3114.0      25.0       25.0   12.0    12.0
# 2      775.0    4534.0        3309.0      10.0        8.0   16.0     9.0
# 3      861.0    4398.0        3469.0       6.0        6.0   10.0    11.0
# 4      920.0    4631.0        3700.0       8.0        7.0   10.0     5.0
#
#    Fifth  Sixth     T    Debut Since/LastApp  BestPosition
# ...

# %%
new_df = df3.loc[(df3['Debut'] >= '1930') & (df3['Debut'] <= '1980')]
new_df.Debut
# Out:
# 3     1931-32
# 5     1934-35
# 8     1939-40
# 9     1932-33
# 10    1941-42
# 11    1939-40
# 12    1948-49
# 14    1944-45
# 15    1935-36
# 16    1949-50
# 17    1933-34
# 18    1960-61
# 19    1951-52
# 21    1941-42
# 22    1977-78
# 23    1959-60
# 25    1935-36
# 26    1961-62
# 27    1940-41
# 28    1930-31
# 29    1963-64
# 30    1974-75
# 31    1943-44
# 32    1977-78
# 34    1941-42
# 37    1962-63
# 39    1978-79
# 40    1971-72
# 41    1963-64
# 46    1947-48
# 49    1945-46
# 50    1953-54
# 52    1979-80
# 54    1950-51
# 57    1956-57
# 58    1951-52
# 59    1955-56
# Name: Debut, dtype: object

# %% [markdown]
# Print the list of teams which came Top 5 in terms of points

# %%
df3.head()  # the data is already in sorting order with respect to "Points" column.
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 0    1      Real Madrid       86  4385.0       2762.0    1647.0       552.0
# 1    2        Barcelona       86  4262.0       2762.0    1581.0       573.0
# 2    3  Atletico Madrid       80  3442.0       2614.0    1241.0       598.0
# 3    4         Valencia       82  3386.0       2664.0    1187.0       616.0
# 4    5  Athletic Bilbao       86  3368.0       2762.0    1209.0       633.0
#
#    GamesLost  GoalsFor  GoalsAgainst       ...         Third  Fourth  Fifth  \
# 0      563.0    5947.0        3140.0       ...           8.0     8.0    3.0
# 1      608.0    5900.0        3114.0       ...          12.0    12.0    4.0
# 2      775.0    4534.0        3309.0       ...          16.0     9.0    7.0
# 3      861.0    4398.0        3469.0       ...          10.0    11.0   10.0
# 4      920.0    4631.0        3700.0       ...          10.0     5.0    8.0
#
# ...

# %% [markdown]
# Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference.

# %%
def Goal_diff_count(goalsFor, goalsAgainst):
    return goalsFor - goalsAgainst

# %%
Goal_diff_count(df3.GoalsFor, df3.GoalsAgainst).max()
# Out:
# 2807.0

# %%
Goal_diff_count(df3.GoalsFor, df3.GoalsAgainst).min()
# Out:
# -525.0

# %%
df5 = df3

# %%
df5.head(10)
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 0    1      Real Madrid       86  4385.0       2762.0    1647.0       552.0
# 1    2        Barcelona       86  4262.0       2762.0    1581.0       573.0
# 2    3  Atletico Madrid       80  3442.0       2614.0    1241.0       598.0
# 3    4         Valencia       82  3386.0       2664.0    1187.0       616.0
# 4    5  Athletic Bilbao       86  3368.0       2762.0    1209.0       633.0
# 5    6          Sevilla       73  2819.0       2408.0     990.0       531.0
# 6    7         Espanyol       82  2792.0       2626.0     948.0       608.0
# 7    8    Real Sociedad       70  2573.0       2302.0     864.0       577.0
# 8    9         Zaragoza       58  2109.0       1986.0     698.0       522.0
# 9   10       Real Betis       51  1884.0       1728.0     606.0       440.0
#
#    GamesLost  GoalsFor  GoalsAgainst       ...         Runner-up  Third  \
# ...

# %% [markdown]
# Create a new column with name “Winning Percent” and append it to the data set

# %%
df5["Winning Percent"] = (df5.GamesWon / df5.GamesPlayed) * 100

# %%
df5
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0     1          Real Madrid       86  4385.0       2762.0    1647.0
# 1     2            Barcelona       86  4262.0       2762.0    1581.0
# 2     3      Atletico Madrid       80  3442.0       2614.0    1241.0
# 3     4             Valencia       82  3386.0       2664.0    1187.0
# 4     5      Athletic Bilbao       86  3368.0       2762.0    1209.0
# 5     6              Sevilla       73  2819.0       2408.0     990.0
# 6     7             Espanyol       82  2792.0       2626.0     948.0
# 7     8        Real Sociedad       70  2573.0       2302.0     864.0
# 8     9             Zaragoza       58  2109.0       1986.0     698.0
# 9    10           Real Betis       51  1884.0       1728.0     606.0
# 10   11  Deportivo La Coruna       45  1814.0       1530.0     563.0
# 11   12           Celta Vigo       51  1789.0       1698.0     586.0
# 12   13           Valladolid       42  1471.0       1466.0     463.0
# ...

# %% [markdown]
# Print the top 5 teams which has the highest Winning percentage

# %%
df6 = df5.sort_values(by="Winning Percent", ascending=False)
df6.head()
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 0    1      Real Madrid       86  4385.0       2762.0    1647.0       552.0
# 1    2        Barcelona       86  4262.0       2762.0    1581.0       573.0
# 2    3  Atletico Madrid       80  3442.0       2614.0    1241.0       598.0
# 3    4         Valencia       82  3386.0       2664.0    1187.0       616.0
# 4    5  Athletic Bilbao       86  3368.0       2762.0    1209.0       633.0
#
#    GamesLost  GoalsFor  GoalsAgainst       ...         Third  Fourth  Fifth  \
# 0      563.0    5947.0        3140.0       ...           8.0     8.0    3.0
# 1      608.0    5900.0        3114.0       ...          12.0    12.0    4.0
# 2      775.0    4534.0        3309.0       ...          16.0     9.0    7.0
# 3      861.0    4398.0        3469.0       ...          10.0    11.0   10.0
# 4      920.0    4631.0        3700.0       ...          10.0     5.0    8.0
#
# ...

# %% [markdown]
# Group teams based on their “Best position” and print the sum of their points for all positions

# %%
df5.groupby("BestPosition")[["Points"]].sum()
# Out:
#                Points
# BestPosition
# 1             27933.0
# 2              6904.0
# 3              5221.0
# 4              6563.0
# 5              1884.0
# 6              2113.0
# 7              1186.0
# 8              1134.0
# 9                96.0
# 10              450.0
# 11              445.0
# 12              511.0
# 14               71.0
# 15               14.0
# 16               81.0
# 17              266.0
# 19               81.0
# 20               34.0
